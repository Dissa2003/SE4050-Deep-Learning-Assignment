# %% [markdown]
# # 03 - Deep Learning Models
#
# SE4050 Deep Learning Assignment - Brain Tumor Classification
#
# This notebook builds, trains, and evaluates CNN-based deep learning models using PyTorch.

# %%
import sys
sys.path.append('..')

import torch
from torch import nn, optim
from torch.utils.data import DataLoader

from src.dataset import BrainTumorDataset
from src.models import SimpleCNN
from src.utils import train_one_epoch, evaluate, save_checkpoint

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
